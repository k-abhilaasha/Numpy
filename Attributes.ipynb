# %% [markdown]
# <a href="https://colab.research.google.com/github/k-abhilaasha/Numpy/blob/main/Attributes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5])
arr1.shape
# Out:
# (5,)

# %%
arr2=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
arr2
# arr2.shape
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
arr2.ndim
# Out:
# 3

# %%
arr2.size
# Out:
# 8

# %%
arr2.itemsize
# Out:
# 8

# %%
arr6=np.linspace(1,10,5)
arr6
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
arr6.itemsize

# %%
arr6.nbytes
# Out:
# 40

# %%
arr6.astype('int')
# Out:
# array([ 1,  3,  5,  7, 10])
