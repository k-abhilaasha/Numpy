# %% [markdown]
# <a href="https://colab.research.google.com/github/k-abhilaasha/Numpy/blob/main/Numpy_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.array([4,5,6,7,8,9])

# %%
arr1-arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
arr1+arr2
# Out:
# array([ 5,  7,  9, 11, 13, 15])

# %%
arr1*arr2
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
arr1*2
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
arr2>5
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
arr3=np.arange(6).reshape(2,3)
arr4=np.arange(6,12).reshape(3,2)

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# np.int64(154)

# %%
arr1.dot(arr3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_675/2309766231.py in <cell line: 0>()
# ----> 1 arr1.dot(arr3)
#
# ValueError: shapes (6,) and (2,3) not aligned: 6 (dim 0) != 2 (dim 0)

# %%
arr4.min()
# Out:
# np.int64(6)

# %%
arr4.max()
# Out:
# np.int64(11)

# %%
arr4.min(axis=0)
# Out:
# array([6, 7])

# %%
arr4.min(axis=1)
# Out:
# array([ 6,  8, 10])

# %%
arr4.max(axis=0)
# Out:
# array([10, 11])

# %%
arr4.max(axis=1)
# Out:
# array([ 7,  9, 11])

# %%
arr4.sum()
# Out:
# np.int64(51)

# %%
arr4.sum(axis=0)
# Out:
# array([24, 27])

# %%
arr4.sum(axis=1)
# Out:
# array([13, 17, 21])

# %%
arr4.mean()
# Out:
# np.float64(8.5)

# %%
np.median(arr4)
# Out:
# np.float64(8.5)

# %%
np.sin(arr4)
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
arr4.std()
# Out:
# np.float64(1.707825127659933)

# %%
np.sqrt(arr4)
# Out:
# array([[2.44948974, 2.64575131],
#        [2.82842712, 3.        ],
#        [3.16227766, 3.31662479]])

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])
