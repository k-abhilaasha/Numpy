# %% [markdown]
# <a href="https://colab.research.google.com/github/k-abhilaasha/Numpy/blob/main/Plotting_Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x=np.linspace(-40,40,100)

# %%
x.size
# Out:
# 100

# %%
y=np.sin(x)

# %%
y.size
# Out:
# 100

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
y=x*x+2*x+4
plt.plot(x,y)
