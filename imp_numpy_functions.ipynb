# %% [markdown]
# <a href="https://colab.research.google.com/github/k-abhilaasha/Numpy/blob/main/imp_numpy_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

# %%
np.random.random()
# Out:
# 0.7807790657842357

# %%
np.random.seed(1)
num=np.random.randint(1,50,10)
num
# Out:
# array([38, 44, 13,  9, 10, 12,  6, 16,  1, 17])

# %%
np.random.uniform(3,10)
# Out:
# 5.192914618525926

# %%
np.random.uniform(1,100,10).reshape(5,2)
# Out:
# array([[83.08554383, 83.13073258],
#        [28.03194745,  6.86507693],
#        [67.38227597, 59.71348631],
#        [67.49375564, 41.76700002],
#        [20.5575389 , 29.67333441]])

# %%
num.max()
# Out:
# np.int64(44)

# %%
np.argmax(num)
# Out:
# np.int64(1)

# %%
np.where(num%2==0,num,-1)
# Out:
# array([38, 44, -1, -1, 10, 12,  6, 16, -1, -1])

# %%
np.percentile(num,75)
# Out:
# np.float64(16.75)
