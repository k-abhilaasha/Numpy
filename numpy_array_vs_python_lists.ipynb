# %% [markdown]
# <a href="https://colab.research.google.com/github/k-abhilaasha/Numpy/blob/main/numpy_array_vs_python_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
lista=range(100)
arr1=np.arange(100)

# %%
import sys

# %%
print(sys.getsizeof(1)*len(lista))
# Out:
# 2800

# %%
print(arr1.itemsize*arr1.size)
# Out:
# 800

# %%
import time

# %%
x=range(10000000)
y=range(10000000,20000000)
start_time=time.time()
s=[x+y for x,y in zip(x,y)]
print(time.time()-start_time)
# Out:
# 0.9129400253295898

# %%
a=np.arange(10000000)
b=np.arange(10000000,20000000)
start_time=time.time()
c=a+b
print(time.time()-start_time)
# Out:
# 0.034104108810424805
